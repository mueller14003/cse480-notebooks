# %% [markdown]
# <a href="https://colab.research.google.com/github/mueller14003/cse480-notebooks/blob/master/14_1_My_Final_Grade_Claim_for_W21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Final Grade Claim for CSE 480 W21

# %% [markdown]
# ![final-grade-claim-decision-cse480.png](data:image/png;base64,...)

# %% [markdown]
# ## Top 3 Evidences

# %% [markdown]
# ### Evidence 1 - ___

# %% [markdown]
# ### Evidence 2 - ___

# %% [markdown]
# ### Evidence 3 - ___
